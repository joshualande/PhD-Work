# %% [markdown]
# # Take derivative of a polynomial using sympy

# %% [markdown]
# In this notebook, we will work with the variable $x$.

# %%
import sympy
x = sympy.symbols('x')

# %% [markdown]
# Create a polynomial

# %% [markdown]
# First, we can

# %%
f = 10*x**4 + 2*x**3 + 1*x**2 + 22*x + 45
f
# Out:
# 10*x**4 + 2*x**3 + x**2 + 22*x + 45

# %%
sympy.diff(f, x)
# Out:
# 40*x**3 + 6*x**2 + 2*x + 22

# %% [markdown]
# What if you have a polynomial you want to expand:

# %%
f = (10*x**3 + 2*x**2 + 1*x + 4)*(8*x**2 + 4*x + 2)

# %%
sympy.expand(f)
# Out:
# 80*x**5 + 56*x**4 + 36*x**3 + 40*x**2 + 18*x + 8

# %%
a,b,c,d = sympy.symbols('a b c d')
f=(a*x+b)*(c*x+d)
f=sympy.expand(f)

# %% [markdown]
# What if you have multiple a and b in a list

# %%
zip([1,2,3],[4,5,6])
# Out:
# [(1, 4), (2, 5), (3, 6)]

# %%
a=[10,2,5,4,200,2,1]
b=[22,7,9,3,5,55]
f=1
for _a, _b, in zip(a,b):
    f *= (_a*x+_b)
f = sympy.expand(f)
f
# Out:
# 160000*x**6 + 5724000*x**5 + 40216600*x**4 + 109148640*x**3 + 124618870*x**2 + 48785880*x + 1143450

# %% [markdown]
# Will this work with 1000 terms

# %%
a,b = np.random.rand(2,1000)
f=1
for _a, _b, in zip(a,b):
    f *= (_a*x+_b)
f = sympy.expand(f)
f
# Out:
# 2.3866653056638e-437*x**1000 + 4.92915180305793e-433*x**999 + 2.47885535062486e-429*x**998 + 6.32712122638943e-426*x**997 + 1.03754465059238e-422*x**996 + 1.22636974911805e-419*x**995 + 1.11787370454388e-416*x**994 + 8.21354152347046e-414*x**993 + 5.01827022163741e-411*x**992 + 2.60905726116191e-408*x**991 + 1.17500578314273e-405*x**990 + 4.64895179567862e-403*x**989 + 1.63462332567583e-400*x**988 + 5.15665378701896e-398*x**987 + 1.47128986207193e-395*x**986 + 3.82292278116694e-393*x**985 + 9.10007544687275e-391*x**984 + 1.99483478010254e-388*x**983 + 4.04552786842128e-386*x**982 + 7.62118294886306e-384*x**981 + 1.338552174435e-381*x**980 + 2.19909092930581e-379*x**979 + 3.38953769945745e-377*x**978 + 4.91479399350496e-375*x**977 + 6.72070632384999e-373*x**976 + 8.68676647659427e-371*x**975 + 1.06352135485434e-368*x**974 + 1.23572445690361e-366*x**973 + 1.36510447732058e-364*x**972 + 1.43617016016466e-362*x**971 + 1.44118490022046e-360*x**970 + 1.38146953009424e-358*x**969 + 1.266674
# ...
