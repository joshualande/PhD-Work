# %% [markdown]
# # Basic Plotting
#
# 02/28/2013 -I am just testing out very basic matplotlib functionality in ipython notebook. Since I ran ipython with the -pylab flag, I don't have to import pylab!

# %%
pylab.plot([1,2,3],[4,5,6])

# %% [markdown]
# # pywcsgrid example
#
# 02/04/2013 - Testing out pywcsgrid2

# %%
import pywcsgrid2, pyfit
from os.path import expandvars

# %% [markdown]
# Open up data of Puppis A

# %%
f = pyfits.open(expandvars("$fermi/templates/puppis_a/pup-sm.fits"))
h, d = f[0].header, f[0].data

# %% [markdown]
# Make plot of Puppis A using pywcsgrid2

# %%
pywcsgrid2.subplot(122, header=h)
plt.imshow(d, origin="lower")
